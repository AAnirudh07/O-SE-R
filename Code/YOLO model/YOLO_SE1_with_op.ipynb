# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !ls '/content/drive/My Drive/YOLO_SE1'
# Out:
# backup	custom_data  custom_weight  darknet  ezyzip.zip

# %%
# !unzip '/content/drive/My Drive/YOLO_SE1/ezyzip.zip' -d '/content/drive/My Drive/YOLO_SE1/custom_data'
# Out:
# Archive:  /content/drive/My Drive/YOLO_SE1/ezyzip.zip
# replace /content/drive/My Drive/YOLO_SE1/custom_data/1.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/1.jpg
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/1.txt
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/2.jpg
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/2.txt
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/3.jpg
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/3.txt
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/4.jpg
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/4.txt
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/5.jpg
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/5.txt
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/6.jpg
#   inflating: /content/drive/My Drive/YOLO_SE1/custom_data/6.txt
# ...

# %%
# !git clone 'https://github.com/AlexeyAB/darknet.git' '/content/drive/My Drive/YOLO_SE1/darknet'
# Out:
# Cloning into '/content/drive/My Drive/YOLO_SE1/darknet'...
# remote: Enumerating objects: 15420, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 15420 (delta 1), reused 6 (delta 1), pack-reused 15413
# Receiving objects: 100% (15420/15420), 14.08 MiB | 7.75 MiB/s, done.
# Resolving deltas: 100% (10356/10356), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd '/content/drive/My Drive/YOLO_SE1/darknet'
# Out:
# /content/drive/My Drive/YOLO_SE1/darknet

# %%
# !ls
# Out:
# 3rdparty	DarknetConfig.cmake.in	json_mjpeg_streams.sh  scripts
# backup		darknet_images.py	LICENSE		       src
# build		darknet.py		Makefile	       vcpkg.json
# build.ps1	darknet_video.py	net_cam_v3.sh	       video_yolov3.sh
# cfg		data			net_cam_v4.sh	       video_yolov4.sh
# cmake		image_yolov3.sh		obj
# CMakeLists.txt	image_yolov4.sh		README.md
# darknet		include			results

# %%
# !make
# Out:
# chmod +x *.sh

# %%
# !chmod +x darknet/darknet

# %%
# !darknet/darknet
# Out:
# usage: darknet/darknet <function>

# %%
# %cd '/content/drive/My Drive/YOLO_SE1'
# Out:
# /content/drive/My Drive/YOLO_SE1

# %%
# !python custom_data/creating-files-data-and-name.py

# %%
# !python custom_data/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train custom_data/labelled_data.data darknet/cfg/yolov3_custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.918264), count: 5, class_loss = 0.011608, iou_loss = 0.094095, total_loss = 0.105703
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.845358), count: 1, class_loss = 0.710274, iou_loss = 0.046963, total_loss = 0.757237
#  total_bbox = 142903, rewritten_bbox = 0.000700 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.893136), count: 3, class_loss = 0.000685, iou_loss = 0.088955, total_loss = 0.089640
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000009, iou_loss = 0.000000, total_loss = 0.000009
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 0.000001, iou_loss = 0.000000, total_loss = 0.000001
# ...
